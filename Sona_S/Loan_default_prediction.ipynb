# %%
# !ls
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Loan_default.csv  sample_data

# %%
df = pd.read_csv('Loan_default.csv')

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   LoanID          255347 non-null  object
#  1   Age             255347 non-null  int64
#  2   Income          255347 non-null  int64
#  3   LoanAmount      255347 non-null  int64
#  4   CreditScore     255347 non-null  int64
#  5   MonthsEmployed  255347 non-null  int64
#  6   NumCreditLines  255347 non-null  int64
#  7   InterestRate    255347 non-null  float64
#  8   LoanTerm        255347 non-null  int64
#  9   DTIRatio        255347 non-null  float64
#  10  Education       255347 non-null  object
#  11  EmploymentType  255347 non-null  object
#  12  MaritalStatus   255347 non-null  object
#  13  HasMortgage     255347 non-null  object
#  14  HasDependents   255347 non-null  object
#  15  LoanPurpose     255347 non-null  object
# ...

# %%
print(df.isnull().sum())
# Out:
# LoanID            0
# Age               0
# Income            0
# LoanAmount        0
# CreditScore       0
# MonthsEmployed    0
# NumCreditLines    0
# InterestRate      0
# LoanTerm          0
# DTIRatio          0
# Education         0
# EmploymentType    0
# MaritalStatus     0
# HasMortgage       0
# HasDependents     0
# LoanPurpose       0
# HasCoSigner       0
# Default           0
# dtype: int64

# %%
sns.set_style("whitegrid")

# %%
numerical_cols = ['Age', 'Income', 'LoanAmount', 'CreditScore', 'MonthsEmployed', 'NumCreditLines', 'InterestRate', 'LoanTerm', 'DTIRatio']
categorical_cols = ['Education', 'EmploymentType', 'MaritalStatus', 'HasMortgage', 'HasDependents', 'LoanPurpose', 'HasCoSigner']
plt.figure(figsize=(15, 15))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(3, 3, i)
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 20))
for i, col in enumerate(categorical_cols, 1):
    plt.subplot(4, 2, i)
    sns.countplot(data=df, y=col, order=df[col].value_counts().index)
    plt.title(f'Count of {col}')
    plt.xlabel('Count')
    plt.ylabel(col)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
from IPython.display import display

# Define the schema mapping in a dictionary
schema_data = {
    'Column Name': ['LoanID', 'Age', 'Income', 'LoanAmount', 'CreditScore', 'MonthsEmployed', 'NumCreditLines', 'Education', 'EmploymentType', 'MaritalStatus', 'HasMortgage', 'HasDependents', 'LoanPurpose', 'HasCoSigner', 'InterestRate', 'LoanTerm', 'DTIRatio', 'Default'],
    'Data Type': ['Object', 'Integer', 'Integer', 'Integer', 'Integer', 'Integer', 'Integer', 'Object', 'Object', 'Object', 'Object', 'Object', 'Object', 'Object', 'Float', 'Integer', 'Float', 'Integer'],
    'Description': [
        'A unique identifier for each loan.',
        'The age of the loan applicant.',
        'The annual income of the applicant.',
        'The requested loan amount.',
        'The credit score of the applicant.',
        'The number of months the applicant has been employed.',
        'The total number of credit lines an applicant has.',
        'The educational background of the applicant.',
        'The employment status of the applicant.',
        'The marital status of the applicant.',
        'Indicates whether the applicant has a mortgage (Yes/No).',
        'Indicates whether the applicant has dependents (Yes/No).',
        'The stated purpose for the loan.',
        'Indicates whether the loan has a co-signer (Yes/No).',
        'The interest rate for the loan.',
        'The duration of the loan in months.',
        'The Debt-to-Income ratio of the applicant.',
        'The target variable, indicating if the loan was defaulted (1) or not (0).'
    ]
}

# Create a pandas DataFrame from the dictionary
schema_df = pd.DataFrame(schema_data)

# Use the display function to render a formatted table
print("--- Dataset Schema: Loan_default.csv ---")
display(schema_df)
# Out:
# --- Dataset Schema: Loan_default.csv ---
#        Column Name Data Type  \
# 0           LoanID    Object
# 1              Age   Integer
# 2           Income   Integer
# 3       LoanAmount   Integer
# 4      CreditScore   Integer
# 5   MonthsEmployed   Integer
# 6   NumCreditLines   Integer
# 7        Education    Object
# 8   EmploymentType    Object
# 9    MaritalStatus    Object
# 10     HasMortgage    Object
# 11   HasDependents    Object
# 12     LoanPurpose    Object
# 13     HasCoSigner    Object
# 14    InterestRate     Float
# 15        LoanTerm   Integer
# 16        DTIRatio     Float
# 17         Default   Integer
#
#                                           Description
# 0                  A unique identifier for each loan.
# 1                      The age of the loan applicant.
# 2                 The annual income of the applicant.
# 3                          The requested loan amount.
# 4                  The credit score of the applicant.
# ...
